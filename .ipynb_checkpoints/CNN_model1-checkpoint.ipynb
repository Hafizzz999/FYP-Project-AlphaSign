# %%
# Part 1 - Building the CNN
# Importing the TensorFlow and Keras libraries and packages
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import optimizers

# Initialing the CNN
classifier = Sequential()

# Step 1 - Convolution Layer 
classifier.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Adding second convolution layer
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Adding 3rd Convolution Layer
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full Connection
classifier.add(Dense(256, activation='relu'))
classifier.add(Dropout(0.5))
classifier.add(Dense(26, activation='softmax'))

# Compiling The CNN
classifier.compile(optimizer=optimizers.SGD(learning_rate=0.01),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# Part 2 Fitting the CNN to the images
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('Dataset/training_set', target_size=(64, 64), batch_size=32, class_mode='categorical')
test_set = test_datagen.flow_from_directory('Dataset/test_set', target_size=(64, 64), batch_size=32, class_mode='categorical')

model = classifier.fit(training_set, steps_per_epoch=140, epochs=30, validation_data=test_set, validation_steps=203)

# Saving the model
classifier.save('Trained_model1.h5')

# Plotting the training results
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Found 45500 images belonging to 26 classes.
# Found 6500 images belonging to 26 classes.
# Epoch 1/30
# 140/140 [==============================] - 155s 1s/step - loss: 3.2208 - accuracy: 0.0696 - val_loss: 3.1016 - val_accuracy: 0.2118
# Epoch 2/30
# 140/140 [==============================] - 66s 468ms/step - loss: 2.8716 - accuracy: 0.1569 - val_loss: 2.3254 - val_accuracy: 0.4204
# Epoch 3/30
# 140/140 [==============================] - 60s 431ms/step - loss: 2.1905 - accuracy: 0.3261 - val_loss: 1.5022 - val_accuracy: 0.5704
# Epoch 4/30
# 140/140 [==============================] - 56s 402ms/step - loss: 1.6514 - accuracy: 0.4741 - val_loss: 1.0061 - val_accuracy: 0.6981
# Epoch 5/30
# 140/140 [==============================] - 53s 377ms/step - loss: 1.2476 - accuracy: 0.5848 - val_loss: 0.7699 - val_accuracy: 0.7635
# Epoch 6/30
# 140/140 [==============================] - 50s 358ms/step - loss: 1.0530 - accuracy: 0.6577 - val_loss: 0.5732 - val_accuracy: 0.8364
# Epoch 7/30
# 140/140 [==============================] - 47s 338ms/step - loss: 0.8543 - accuracy: 0.7114 - val_loss: 0.4487 - val_accuracy: 0.8859
# Epoch 8/30
# 140/140 [==============================] - 45s 323ms/step - loss: 0.7681 - accuracy: 0.7388 - val_loss: 0.3912 - val_accuracy: 0.8816
# Epoch 9/30
# 140/140 [==============================] - 41s 295ms/step - loss: 0.6735 - accuracy: 0.7783 - val_loss: 0.3110 - val_accuracy: 0.9212
# Epoch 10/30
# 140/140 [==============================] - 39s 281ms/step - loss: 0.5940 - accuracy: 0.8047 - val_loss: 0.3123 - val_accuracy: 0.9078
# Epoch 11/30
# 140/140 [==============================] - 38s 274ms/step - loss: 0.5509 - accuracy: 0.8087 - val_loss: 0.2924 - val_accuracy: 0.9303
# Epoch 12/30
# 140/140 [==============================] - 36s 260ms/step - loss: 0.4968 - accuracy: 0.8366 - val_loss: 0.2246 - val_accuracy: 0.9467
# Epoch 13/30
# 140/140 [==============================] - 34s 245ms/step - loss: 0.4863 - accuracy: 0.8377 - val_loss: 0.2276 - val_accuracy: 0.9507
# Epoch 14/30
# 140/140 [==============================] - 35s 250ms/step - loss: 0.4428 - accuracy: 0.8531 - val_loss: 0.1928 - val_accuracy: 0.9669
# Epoch 15/30
# 140/140 [==============================] - 32s 229ms/step - loss: 0.3893 - accuracy: 0.8670 - val_loss: 0.1750 - val_accuracy: 0.9641
# Epoch 16/30
# 140/140 [==============================] - 30s 217ms/step - loss: 0.4137 - accuracy: 0.8603 - val_loss: 0.1942 - val_accuracy: 0.9586
# Epoch 17/30
# 140/140 [==============================] - 29s 210ms/step - loss: 0.3412 - accuracy: 0.8839 - val_loss: 0.1864 - val_accuracy: 0.9561
# Epoch 18/30
# 140/140 [==============================] - 30s 214ms/step - loss: 0.3478 - accuracy: 0.8855 - val_loss: 0.2333 - val_accuracy: 0.9446
# Epoch 19/30
# 140/140 [==============================] - 29s 209ms/step - loss: 0.3190 - accuracy: 0.8882 - val_loss: 0.1835 - val_accuracy: 0.9589
# Epoch 20/30
# 140/140 [==============================] - 28s 201ms/step - loss: 0.3121 - accuracy: 0.8971 - val_loss: 0.1768 - val_accuracy: 0.9684
# Epoch 21/30
# 140/140 [==============================] - 27s 195ms/step - loss: 0.3158 - accuracy: 0.8913 - val_loss: 0.1823 - val_accuracy: 0.9701
# Epoch 22/30
# 140/140 [==============================] - 27s 193ms/step - loss: 0.2857 - accuracy: 0.9042 - val_loss: 0.1674 - val_accuracy: 0.9600
# Epoch 23/30
# 140/140 [==============================] - 26s 186ms/step - loss: 0.2737 - accuracy: 0.9080 - val_loss: 0.1471 - val_accuracy: 0.9726
# Epoch 24/30
# 140/140 [==============================] - 26s 184ms/step - loss: 0.2513 - accuracy: 0.9161 - val_loss: 0.1239 - val_accuracy: 0.9768
# Epoch 25/30
# 140/140 [==============================] - 25s 178ms/step - loss: 0.2764 - accuracy: 0.9029 - val_loss: 0.1250 - val_accuracy: 0.9706
# Epoch 26/30
# 140/140 [==============================] - 25s 178ms/step - loss: 0.2635 - accuracy: 0.9062 - val_loss: 0.1363 - val_accuracy: 0.9783
# Epoch 27/30
# 140/140 [==============================] - 25s 178ms/step - loss: 0.2405 - accuracy: 0.9165 - val_loss: 0.1192 - val_accuracy: 0.9818
# Epoch 28/30
# 140/140 [==============================] - 23s 165ms/step - loss: 0.2249 - accuracy: 0.9208 - val_loss: 0.1215 - val_accuracy: 0.9769
# Epoch 29/30
# 140/140 [==============================] - 23s 165ms/step - loss: 0.2485 - accuracy: 0.9170 - val_loss: 0.1609 - val_accuracy: 0.9675
# Epoch 30/30
# 140/140 [==============================] - 24s 171ms/step - loss: 0.2042 - accuracy: 0.9308 - val_loss: 0.1190 - val_accuracy: 0.9812
