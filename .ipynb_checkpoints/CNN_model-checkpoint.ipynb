# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [39 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 35, in __init__
#       parsed = _parse_requirement(requirement_string)
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 64, in parse_requirement
#       return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 82, in _parse_requirement
#       url, specifier, marker = _parse_requirement_details(tokenizer)
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 126, in _parse_requirement_details
#       marker = _parse_requirement_marker(
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 147, in _parse_requirement_marker
#       tokenizer.raise_syntax_error(
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\_tokenizer.py", line 165, in raise_syntax_error
#       raise ParserSyntaxError(
#   setuptools.extern.packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after name and no valid version specifier)
#       python_version>"3.7"
#                     ^
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\HP\AppData\Local\Temp\pip-install-my7ngtvy\tensorflow-gpu_44b58c2bdc944990806f9a8cd3aad128\setup.py", line 40, in <module>
#       setuptools.setup()
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\__init__.py", line 106, in setup
#       _install_setup_requires(attrs)
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\__init__.py", line 77, in _install_setup_requires
#       dist.parse_config_files(ignore_option_errors=True)
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\dist.py", line 900, in parse_config_files
#       self._finalize_requires()
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\dist.py", line 597, in _finalize_requires
#       self._move_install_requirements_markers()
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\dist.py", line 637, in _move_install_requirements_markers
#       inst_reqs = list(_reqs.parse(spec_inst_reqs))
#     File "C:\Users\HP\anaconda3\envs\alphasign\lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 37, in __init__
#       raise InvalidRequirement(str(e)) from e
#   setuptools.extern.packaging.requirements.InvalidRequirement: Expected end or semicolon (after name and no valid version specifier)
#       python_version>"3.7"
#                     ^
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Importing required libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)

# GPU configuration
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Check if TensorFlow can access the GPU
if not tf.test.gpu_device_name():
    raise SystemError('GPU device not found')
print('Found GPU at:', tf.test.gpu_device_name())

# Check CUDA and cuDNN availability
if not tf.test.is_built_with_cuda():
    raise SystemError('TensorFlow not built with CUDA')
print('TensorFlow built with CUDA')

# Initialing the CNN
classifier = Sequential()

# Step 1 - Convolution Layer 
classifier.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size=(2,2)))

# Adding second convolution layer
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))

# Adding 3rd Convolution Layer
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full Connection
classifier.add(Dense(256, activation='relu'))
classifier.add(Dropout(0.5))
classifier.add(Dense(26, activation='softmax'))

# Compiling The CNN with updated learning rate syntax
classifier.compile(optimizer=SGD(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# Image Data Augmentation and Loading
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('Dataset/training_set', target_size=(64, 64), batch_size=32, class_mode='categorical')
test_set = test_datagen.flow_from_directory('Dataset/test_set', target_size=(64, 64), batch_size=32, class_mode='categorical')

# Using ModelCheckpoint to save the best model
checkpoint = ModelCheckpoint('best_model.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='auto')

# Fitting the CNN to the images
model = classifier.fit(
    training_set,
    steps_per_epoch=800, 
    epochs=25,
    validation_data=test_set,
    validation_steps=6500,
    callbacks=[checkpoint]
)

# Plotting graphs for accuracy and loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# TensorFlow version: 2.10.1
# Found GPU at: /device:GPU:0
# TensorFlow built with CUDA
# Found 45500 images belonging to 26 classes.
# Found 6500 images belonging to 26 classes.
# Epoch 1/25
# 800/800 [==============================] - ETA: 0s - loss: 2.1743 - accuracy: 0.3461WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6500 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 1: val_loss improved from inf to 0.63384, saving model to best_model.h5
# 800/800 [==============================] - 239s 285ms/step - loss: 2.1743 - accuracy: 0.3461 - val_loss: 0.6338 - val_accuracy: 0.8206
# Epoch 2/25
# 800/800 [==============================] - ETA: 0s - loss: 0.6741 - accuracy: 0.7739WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 91s 114ms/step - loss: 0.6741 - accuracy: 0.7739
# Epoch 3/25
# 800/800 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8580WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 65s 81ms/step - loss: 0.4132 - accuracy: 0.8580
# Epoch 4/25
# 800/800 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8945WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 52s 65ms/step - loss: 0.3034 - accuracy: 0.8945
# Epoch 5/25
# 800/800 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9178WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 45s 56ms/step - loss: 0.2396 - accuracy: 0.9178
# Epoch 6/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9299WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 41s 52ms/step - loss: 0.1988 - accuracy: 0.9299
# Epoch 7/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9388WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 41s 51ms/step - loss: 0.1734 - accuracy: 0.9388
# Epoch 8/25
# 800/800 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9491WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.1452 - accuracy: 0.9491
# Epoch 9/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9521WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 39s 49ms/step - loss: 0.1331 - accuracy: 0.9521
# Epoch 10/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.1166 - accuracy: 0.9587WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.1166 - accuracy: 0.9588
# Epoch 11/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9607WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.1136 - accuracy: 0.9606
# Epoch 12/25
# 800/800 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 39s 49ms/step - loss: 0.1064 - accuracy: 0.9625
# Epoch 13/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9669WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 100s 125ms/step - loss: 0.0938 - accuracy: 0.9669
# Epoch 14/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9697WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 114s 142ms/step - loss: 0.0848 - accuracy: 0.9697
# Epoch 15/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 80s 100ms/step - loss: 0.0795 - accuracy: 0.9712
# Epoch 16/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9751WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 126s 158ms/step - loss: 0.0748 - accuracy: 0.9751
# Epoch 17/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9736WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 75s 94ms/step - loss: 0.0731 - accuracy: 0.9736
# Epoch 18/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9754WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 57s 71ms/step - loss: 0.0715 - accuracy: 0.9754
# Epoch 19/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9775WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 53s 66ms/step - loss: 0.0666 - accuracy: 0.9775
# Epoch 20/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9779WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 44s 54ms/step - loss: 0.0658 - accuracy: 0.9779
# Epoch 21/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9794WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 42s 52ms/step - loss: 0.0599 - accuracy: 0.9794
# Epoch 22/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9807WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.0566 - accuracy: 0.9807
# Epoch 23/25
# 800/800 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9810WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.0569 - accuracy: 0.9810
# Epoch 24/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9835WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.0497 - accuracy: 0.9836
# Epoch 25/25
# 799/800 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 800/800 [==============================] - 40s 50ms/step - loss: 0.0445 - accuracy: 0.9845
